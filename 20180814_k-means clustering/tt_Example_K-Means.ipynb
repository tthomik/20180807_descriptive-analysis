# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# erste Punktwolke
x_werte = np.random.normal(1,1,1000)
y_werte = np.random.normal(1,1,1000)

# zweite Punktwolke
x_werte_2 = np.random.normal(1.5,1,1000)
y_werte_2 = np.random.normal(1.5,1,1000)


# erstelle ich einen zusammengesetzten Datensatz
data_x = np.concatenate([x_werte, x_werte_2])
data_y = np.concatenate([y_werte, y_werte_2])



dataset = pd.DataFrame()

dataset['x'] = data_x
dataset['y'] = data_y

dataset.head()

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0).fit(dataset)
dataset['cluster_nr'] = kmeans.predict(dataset)

# plotte ich diesen Datensatz mit 'scatter'
plt.figure(1, figsize=(6, 6))
plt.scatter(data_x, data_y, c=dataset['cluster_nr'])
plt.show();

# %%
# Anzahl der Cluster --> Abhängig von Anzahl der Cluster können selt
# erste Punktwolke
p1_x_werte = np.random.normal(1,1,1000)
p1_y_werte = np.random.normal(1,1,1000)

# zweite Punktwolke
p1_x_werte_2 = np.random.normal(1.5,1,1000)
p1_y_werte_2 = np.random.normal(1.5,1,1000)


# erstelle ich einen zusammengesetzten Datensatz
p1_data_x = np.concatenate([p1_x_werte, p1_x_werte_2])
p1_data_y = np.concatenate([p1_y_werte, p1_y_werte_2])



p1_dataset = pd.DataFrame()

p1_dataset['x'] = p1_data_x
p1_dataset['y'] = p1_data_y

dataset.head()

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0).fit(p1_dataset)
p1_dataset['cluster_nr'] = kmeans.predict(p1_dataset)

# plotte ich diesen Datensatz mit 'scatter'
plt.figure(1, figsize=(6, 6))
plt.scatter(p1_data_x, p1_data_y, c=p1_dataset['cluster_nr'])
plt.show();
